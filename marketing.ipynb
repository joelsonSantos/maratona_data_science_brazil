# %%
import pandas as pd

dataset = pd.read_csv("train.csv", sep=';')
display(dataset.columns)
classes = dataset['y'] # target
new_columns = ['job', 'marital', 'education', 'default', 
               'housing', 'loan', 'contact', 'month',
              'day_of_week', 'duration', 'poutcome']
df_prep = pd.get_dummies(dataset, prefix_sep="_", columns=new_columns)
display(df_prep)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-7b21a9efbdfb> in <module>()
#       8                'housing', 'loan', 'contact', 'month',
#       9               'day_of_week', 'duration', 'poutcome']
# ---> 10 df_prep = pd.get_dummies(dataset, prefix_sep="_", columns=new_columns)
#      11 display(df_prep)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     842                 include=dtypes_to_encode)
#     843         else:
# ...

# %%
display(dataset.groupby('housing').count())
# Out:
#               age   job  marital  education  default  housing  loan  contact  \
# poutcome
# failure       331   331      331        331      331      331   331      331
# nonexistent  2567  2567     2567       2567     2567     2567  2567     2567
# success       101   101      101        101      101      101   101      101
#
#              month  day_of_week  duration  campaign  pdays  previous  \
# poutcome
# failure        331          331       331       331    331       331
# nonexistent   2567         2567      2567      2567   2567      2567
# success        101          101       101       101    101       101
#
#              emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# poutcome
# failure               331             331            331        331
# nonexistent          2567            2567           2567       2567
# success               101             101            101        101
#
#              nr.employed     y
# poutcome
# ...
